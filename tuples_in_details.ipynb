# %% [markdown]
# **1. Basic Operations**

# %%
thistuple = ("apple","lichi","banana")
print(type(thistuple))
print(thistuple)
# Out:
# <class 'tuple'>
# ('apple', 'lichi', 'banana')

# %%
print(len(thistuple))
# Out:
# 3

# %%
new_tuple = ("apple",)
print(len(new_tuple))
print(new_tuple)
# Out:
# 1
# ('apple',)

# %% [markdown]
# **By using constructor method **

# %%
constructors = tuple(("apple","Banana","cherry","lichi"))
print(constructors)
# Out:
# ('apple', 'Banana', 'cherry', 'lichi')

# %% [markdown]
# **2. Accessing Tuple items**

# %%
t1 = ("apple","lichi","banana","lau")

# %%
print(t1[2])
# Out:
# banana

# %%
print(t1[-1])
# Out:
# lau

# %%
print(t1[1:3])
# Out:
# ('lichi', 'banana')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[-4:-1])
# Out:
# ('orange', 'kiwi', 'melon')

# %% [markdown]
# **3. Change tuple value**

# %% [markdown]
# **NB:**
# We can't directly change the tuple value, what we can do, we can change the tuple to a list, then we can do manipulation, after that, we will convert it to a tuple

# %%
x = ("apple","banana", "cherry")
y = list(x)
y[2] = "papaya"
x = tuple(y)
print(x)
# Out:
# ('apple', 'banana', 'papaya')

# %%
x = ("apple","banana", "cherry")
y = list(x)
y.append("lemon")
x = tuple(y)
print(x)
# Out:
# ('apple', 'banana', 'cherry', 'lemon')

# %%
x = ('apple', 'banana', 'cherry', 'lemon')
y = list(x)
y.remove('lemon')
x = tuple(y)
print(x)
# Out:
# ('apple', 'banana', 'cherry')

# %%
del x

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3023/1353120783.py in <cell line: 0>()
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# **4. Unpacking a tuple**

# %%
fruits = ("apple", "banana", "cherry")
(green, yellow, red) = fruits
print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")
(green, yellow, *rest) = fruits
print(green)
print(yellow)
print(rest)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %% [markdown]
# **5. Loop through a tuple**

# %%
thistuple = ("apple", "banana", "cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
for i in range(len(thistuple)):
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %%
i = 0
while(i<len(thistuple)):
  print(thistuple[i])
  i = i+1
# Out:
# apple
# banana
# cherry

# %%
tuple1 = ('a','b','c')
tuple2 = ('d', 'e', 'f')
tuple3 = tuple1 + tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 'd', 'e', 'f')

# %%
tuple1 = ('a','b','c')
news = tuple1 * 3
print(news)
# Out:
# ('a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c')
