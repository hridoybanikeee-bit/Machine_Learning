# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/cars.csv")
df.head(5)
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
X =df.drop("selling_price", axis = 1)
y = df['selling_price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(drop='first',sparse_output=False,dtype=np.int32)
X_train_new = ohe.fit_transform(X_train[['fuel','owner']])
X_test_new = ohe.transform(X_test[['fuel','owner']])

# %%
np.hstack((X_train[['brand','km_driven']].values,X_train_new))
# Out:
# array([['Tata', 2560, 0, ..., 0, 0, 0],
#        ['Honda', 80000, 0, ..., 1, 0, 0],
#        ['Hyundai', 150000, 1, ..., 0, 0, 0],
#        ...,
#        ['Hyundai', 35000, 0, ..., 0, 0, 0],
#        ['Maruti', 27000, 1, ..., 0, 0, 0],
#        ['Maruti', 70000, 0, ..., 1, 0, 0]], dtype=object)

# %%
X_train_new = pd.DataFrame(
    X_train_new,
    columns=ohe.get_feature_names_out()
)

X_test_new = pd.DataFrame(
    X_test_new,
    columns=ohe.get_feature_names_out())

# %%
X_train_final = pd.concat([X_train.drop(['fuel', 'owner'], axis=1), X_train_new], axis=1)
X_test_final  = pd.concat([X_test.drop(['fuel', 'owner'], axis=1), X_test_new], axis=1)

# %%
X_train_final.head(5)
# Out:
#         brand  km_driven  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 6518     Tata     2560.0          NaN       NaN          NaN
# 6144    Honda    80000.0          1.0       0.0          0.0
# 6381  Hyundai   150000.0          1.0       0.0          0.0
# 438    Maruti   120000.0          1.0       0.0          0.0
# 5939   Maruti    25000.0          1.0       0.0          0.0
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 6518                         NaN                 NaN                   NaN
# 6144                         0.0                 0.0                   0.0
# 6381                         1.0                 0.0                   0.0
# 438                          0.0                 0.0                   0.0
# 5939                         0.0                 0.0                   0.0
#
#       owner_Third Owner
# 6518                NaN
# 6144                0.0
# 6381                0.0
# 438                 0.0
# ...

# %%
df['brand'].nunique()
limit = 100
counts = df['brand'].value_counts()
replaces = counts[counts <= limit].index
pd.get_dummies(df['brand'].replace(replaces, 'uncommon')).sample(5)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 2563  False      False  False  False    False     False   False    False
# 2570  False      False  False  False    False      True   False    False
# 7088  False      False  False  False    False     False    True    False
# 3318  False      False  False  False    False     False   False    False
# 5824  False      False  False  False    False     False   False    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# 2563  False   True   False       False     False
# 2570  False  False   False       False     False
# 7088  False  False   False       False     False
# 3318  False   True   False       False     False
# 5824  False  False   False        True     False

# %%
replaces = counts[counts <= limit].index

# %%
replaces.nunique()
# Out:
# 20
